# %% [markdown]
# SEMANA 5

# %%
#Tupla
numeros = (10, 20, 30, 40, 50)
frutas = ("manzana", "pera", "uva", "mango")
datos = ("Vanessa", 18, 1.65, True)

print(type(numeros))
print(type(frutas))
print(type(datos))

lista =[1]
datos2 = (.5)
print(type(lista))
print(type(datos2))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'list'>
# <class 'float'>

# %%
numeros = (10, 20, 30, 40, 50, 60, 70)

print(numeros[0])   
print(numeros[2])
print(numeros[4])
print(numeros[-1])
# Out:
# 10
# 30
# 50
# 70

# %%
coordenada = (2, 6)

x, y = coordenada

print(f"Coordenada en x: {x}")
print(f"Coordenada en y: {y}")
# Out:
# Coordenada en x: 2
# Coordenada en y: 6

# %%
calificaciones = (88, 90, 100, 85)
calif5 = 50
calif6 = 80
calificaciones = calificaciones + (calif5, calif6)

# %%
desordenada = (9, 2, 7, 10, 0, 8, 14, 22, 4)

print(type(desordenada))
lista = list(desordenada)
print()
print(type(lista))
print(lista)

lista.sort()
print(lista)
ordenada = tuple(lista)
print()
print(type(ordenada))
print(ordenada)
# Out:
# <class 'tuple'>
#
# <class 'list'>
# [9, 2, 7, 10, 0, 8, 14, 22, 4]
# [0, 2, 4, 7, 8, 9, 10, 14, 22]
#
# <class 'tuple'>
# (0, 2, 4, 7, 8, 9, 10, 14, 22)

# %%
def suma_tupla(t):
    total = 0
    for e in t:
        total += e

    return total


calorias = (800, 950, 700, 1300, 800, 900, 650)
resultado = suma_tupla(calorias)
print(f"Metiste a tu cuerpo {resultado} calorías, GORDO!")
# Out:
# Metiste a tu cuerpo 6100 calorías, GORDO!

# %%
contactos = {
    "vane": "9988899760",
    "luis": "9988899770",
    "renata": "9988899780",
}

print(contactos["vane"])
print(contactos.get("raul"))
print(contactos.get("raul", "No existe el contacto"))
# Out:
# 9988899760
# None
# No existe el contacto

# %%
contactos = {
    "vane": "9988899760",
    "luis": "9988899770",
    "renata": "9988899780",
}

contactos["chris"] = "9988899790"
contactos["ricardo"] = "9988609790"

print(contactos)
# Out:
# {'vane': '9988899760', 'luis': '9988899770', 'renata': '9988899780', 'chris': '9988899790', 'ricardo': '9988609790'}

# %%
print(contactos.keys())
print(contactos.values())
print(contactos.items())
# Out:
# dict_keys(['vane', 'luis', 'renata', 'chris', 'ricardo'])
# dict_values(['9988899760', '9988899770', '9988899780', '9988899790', '9988609790'])
# dict_items([('vane', '9988899760'), ('luis', '9988899770'), ('renata', '9988899780'), ('chris', '9988899790'), ('ricardo', '9988609790')])

# %%
print("\nImpresión de llaves ")
for n in contactos.keys():
    print(n)

print("\nImpresion de valores")
for v in contactos.values():
    print(v)

print("\nImpresión completa")
for n, t in contactos.items():
    print(f"Nombre: {n}, Teléfono: {t}")
# Out:
# Impresión de llaves
# vane
# luis
# renata
# chris
# ricardo
#
# Impresion de valores
# 9988899760
# 9988899770
# 9988899780
# 9988899790
# 9988609790
#
# Impresión completa
# Nombre: vane, Teléfono: 9988899760
# Nombre: luis, Teléfono: 9988899770
# Nombre: renata, Teléfono: 9988899780
# Nombre: chris, Teléfono: 9988899790
# Nombre: ricardo, Teléfono: 9988609790

# %%
def buscar_contacto(contactos,nombre):
    return contactos.get(nombre, "No existe el contacto")

nombre = input("Ingresa el nombre del contacto a buscar: ")
resultado = buscar_contacto(contactos, nombre)
print(f"El teléfono de {nombre} es: {resultado}")
# Out:
# El teléfono de chris es: 9988899790

# %%
edad = int(input("Ingresa tu edad: "))
print(f"Tu edad es: {edad}")

try:
    edad = int(input("Ingresa tu edad: "))
    print(f"Tu edad es: {edad}")
except ValueError:
    print("Error: Debes ingresar un número entero para la edad.")
# Out:
# Tu edad es: 3
# Error: Debes ingresar un número entero para la edad.

# %%
try:
    dividendo = int(input("Ingresa el dividendo: "))
    divisor = int(input("Ingresa el divisor: "))
    resultado = dividendo / divisor
except ValueError:
    print("Error de división entre cero.")
else:
    print(f"División exitosa es {resultado}")
finally:
    print("Fue un gusto hacer esta división")
# Out:
# El resultado de la división es: 18.0
# División exitosa es 18.0

# %%
def buscar_contacto(contactos,nombre):
    return contactos.get(nombre, "No existe el contacto")

nombre = input("Ingresa el nombre del contacto a buscar: ")
resultado = buscar_contacto(contactos, nombre)
print(f"El teléfono de {nombre} es: {resultado}")

# %%
def buscar_contacto(contactos,nombre):
    return contactos.get(nombre, "No existe el contacto")

nombre = input("Ingresa el nombre del contacto a buscar: ")
resultado = buscar_contacto(contactos, nombre)
print(f"El teléfono de {nombre} es: {resultado}")

# %%
nombre = "vanessa"

print(nombre.upper())
print(nombre.lower())
print(nombre.capitalize())
# Out:
# VANESSA
# vanessa
# Vanessa

# %% [markdown]
# EJERCICIOS

# %%
#ejercicio 1

espera = ("María", "José", "Carlos", "Lucía", "Pedro")

print(espera[2])

n1 = str(input("Agrega el primer nombre: "))
n2 = str(input("Agrega el segundo nombre: "))
nueva_espera = espera + (n1, n2)

print()
print(nueva_espera)


print(type(nueva_espera))
print(nueva_espera)
lista = list(nueva_espera)
print()

print(type(lista))
print(lista)

lista.sort()
print(lista)

ordenada = tuple(lista)
print(ordenada)
# Out:
# Carlos
#
# ('María', 'José', 'Carlos', 'Lucía', 'Pedro', 'Alma', 'Beto')
# <class 'tuple'>
# ('María', 'José', 'Carlos', 'Lucía', 'Pedro', 'Alma', 'Beto')
#
# <class 'list'>
# ['María', 'José', 'Carlos', 'Lucía', 'Pedro', 'Alma', 'Beto']
# ['Alma', 'Beto', 'Carlos', 'José', 'Lucía', 'María', 'Pedro']
# ('Alma', 'Beto', 'Carlos', 'José', 'Lucía', 'María', 'Pedro')

# %%
#ejercicio 2

candidatos = {
    "A": 0,
    "B": 0,
    "C": 0
}

cantidad = int(input("Ingresa la cantidad de votos que serán registrados: "))

conteo = 1

while conteo <= cantidad:
    voto = input(f"Ingresa tu voto {conteo} (A, B, C): ")
    
    if voto.upper() in candidatos:
        print(f"Voto válido para {voto.upper()}")
        candidatos[voto.upper()] += 1
        conteo += 1
    else:
        print("El voto no es válido")


print("\nResultados")
for k, v in candidatos.items():
    print(f" Opción {k}, votos {v} ")
# Out:
# Voto válido para A
# Voto válido para B
# El voto no es válido
# El voto no es válido
# El voto no es válido
# El voto no es válido
# El voto no es válido
# El voto no es válido
# El voto no es válido
# El voto no es válido
# El voto no es válido
# Voto válido para C
#
# Resultados
#  Opción A, votos 1
#  Opción B, votos 1
#  Opción C, votos 1

# %%
#ejercicio 3

while True:
    try:
        num1 = int(input("Ingresa un número entero: "))
        num2 = int(input("Ingresa un número entero: "))
        division = num1 / num2
    except ValueError:
        print("Error: Debes ingresar un número entero.")
    except ZeroDivisionError:
        print("Error: No se puede dividir entre cero.")
    else:
        print(f"El resultado de la división {division} ")
        break
# Out:
# El resultado de la división 2.0
