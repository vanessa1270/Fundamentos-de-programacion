# %% [markdown]
# #Sesion 1
#
# Este archico es para 2 cosas:
# 1. Familiarizarnos con Jupiter Notebook
# 2. Practicar python

# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %% [markdown]
# ## Variables
#
# Las variables en Python son tipos de datos que tienen diferente forma
#
# -Numéricas
#
#  -Enteros
#  -Flotantes
#
#
# -Cadenas de caracteres
#
# -Booleanos
#
# -Compuestos

# %%
nombre = "Vanessa"
edad = 18
es_estudiante = True
esta_activo =None


print(type(nombre))
print(type(edad))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "Vanessa"
edad = 18

print("Hola", nombre, "ya vi que tienes", edad, "años de edad")
# Out:
# Hola Vanessa ya vi que tienes 18 años de edad

# %% [markdown]
# En este punto, inicializare el proyecto git

# %% [markdown]
# algoritmo para calcular velocidad

# %%
distancia = int(input("Ingresa la distancia en kilometros: "))
tiempo = int(input("Ingresa el tiempo en horas: "))

velocidad = distancia / tiempo

print("la velocidad promedio es: ", velocidad, "km/h")
# Out:
# la velocidad promedio es:  1.3333333333333333 km/h

# %%
a = 4
b = 6

print(a+b)
print(a == b)
print(a != b)
print(a < b)
# Out:
# 10
# False
# True
# True

# %%
nombre = input("Ingresa tu nombre: ")
edad = int(input("Escribe tu edad: "))


print("Hola", nombre, "ya vi que tienes", edad, "años de edad")
# Out:
# Hola vanessa ya vi que tienes 18 años de edad
